# %%
import numpy as np
import networkx as nx

faces = [[21, 22, 23], 
         [22, 23, 24], 
         [22, 24, 27], 
         [22, 26, 27], 
         [22, 25, 26], 
         [24, 27, 28], 
         [24, 28, 31], 
         [28, 30, 31], 
         [28, 29, 30], 
         [24, 31, 32], 
         [31, 32, 34],
         [32, 33, 34]]


spanning_tree = nx.Graph()
spanning_tree.add_edges_from([(0, 1), (1, 2), (2, 3), (3, 4), (2, 5), (5, 6), (6, 7), (7, 8), (6, 9), (9, 10), (10, 11)])


tree_0 = spanning_tree.copy()
tree_1 = spanning_tree.copy()

level_array = np.zeros(len(faces))
# find faces of degree “1” in tree_0 and remove them from tree_1
#use: <graph_name>.degree[face_id]
# <graph_name>.remove_node(face_id)

# replace tree_0 with tree_ 1 and repeat

# iterate till “tree_1.number_of_nodes()” <= 1

# update “level_array” with loop iteration that removes node

nx.draw(spanning_tree, with_labels=True)
